# %% [markdown]
# # Module 3 Peer Review Assignment

# %% [markdown]
# ## 1. Use a new code cell to import functions from the pandas module.

# %%
import pandas as pd

# %% [markdown]
# ## 2. Use a new code cell to read in the ities_short.csv file as a pandas DataFrame, df.

# %%
file_path = "/Assignment/Baking/ities_short.csv"
df = pd.read_csv("ities_short.csv")

# %% [markdown]
# ## 3. Use a new code cell and enter code that will display information and the first five rows of df.

# %%
# %whos
# Out:
# Variable    Type         Data/Info
# ----------------------------------
# df          DataFrame           Unnamed: 0        <...>[80000 rows x 28 columns]
# file_path   str          /Assignment/Baking/ities_short.csv
# pd          module       <module 'pandas' from '/l<...>ages/pandas/__init__.py'>

# %%
df.head()
# Out:
#    Unnamed: 0                  Time OperationType BarCode       CashierName  \
# 0      315839  2014-04-07T15:09:00Z          SALE       *  Trinidad Johnson
# 1       66547  2016-01-14T16:25:00Z          SALE       *      Vincent Ball
# 2        4637  2016-07-02T18:55:00Z          SALE       *     Rachael Price
# 3      274235  2014-07-09T17:11:00Z          SALE       *    Katherine Roth
# 4      331637  2014-03-03T18:39:00Z          SALE       *     Felicia Wolfe
#
#                       LineItem Department                     Category  \
# 0  Salmon and Wheat Bran Salad    Entrees  Salmon and Wheat Bran Salad
# 1        Pork and Pepper Kabob     Kabobs                         Pork
# 2                         Rice      Sides                         Rice
# 3                         Rice      Sides                         Rice
# 4  Salmon and Wheat Bran Salad    Entrees  Salmon and Wheat Bran Salad
#
#      CardholderName RegisterName  ... Discounts NetTotal   Tax  TotalDue  \
# ...

# %% [markdown]
# ## 4. Use a new markdown cell to identify one aspect of df that is tidy and one aspect that is untidy.
#
# - **Tidy Aspect**: Each row in the DataFrame represents a single observation (a purchased item in a transaction), and each column contains a specific variable like `Cost`, `Price`, or `Quantity`.
#
# - **Untidy Aspect**: The `TNumber_LItem` column appears to combine multiple values—possibly a transaction number and an item name—into a single string. Ideally, these should be stored in **separate columns** to make the data easier to analyze and manipulate.

# %% [markdown]
# ## 5. Create a new code cell and enter code to display summary statistics for the numeric columns of data in df.

# %%
df.describe()
# Out:
#           Unnamed: 0          Cost         Price      Quantity     Modifiers  \
# count   80000.000000  80000.000000  80000.000000  80000.000000  80000.000000
# mean   219459.617163      0.341637     14.136813      1.182975      0.629602
# std    126346.937209      5.370029     78.868371      1.565064      2.273839
# min         3.000000   -219.700000  -5740.510000      1.000000   -449.730000
# 25%    110399.750000      0.110000      4.500000      1.000000      0.010000
# 50%    219678.000000      0.110000     11.290000      1.000000      0.010000
# 75%    328472.500000      0.110000     14.680000      1.000000      1.080000
# max    438149.000000    219.520000   7928.000000    120.000000     57.550000
#
#            Subtotal     Discounts      NetTotal           Tax      TotalDue  \
# count  80000.000000  80000.000000  80000.000000  77165.000000  77165.000000
# mean      15.617963      0.974036     14.643928      1.146594     16.110143
# ...

# %%
## 6. Create a new code cell and enter code to display a box plot of the Quantity column of df. Be sure to include a relevant title for the box plot.

# %%
import matplotlib.pyplot as plt

plt.boxplot(df['Quantity'])
plt.title("Box Plot of Quantity Purchased")
plt.ylabel("Quantity")
plt.grid(True)
plt.show()

# %% [markdown]
# ## 7. Create a new markdown cell to describe how the descriptive statistics for the Quantity column from Requirement 5 – the min, 25%, 50%, 75%, and max values – correspond to the box plot of the Quantity column from Requirement 6.

# %% [markdown]
# ## Correspondence Between Box Plot and Descriptive Stats
#
# The box plot of the `Quantity` column reflects the five-number summary from the `.describe()` output:
#
# - **Min**: The lowest value at the start of the whisker.
# - **25% (Q1)**: Lower edge of the box.
# - **50% (Median)**: Line inside the box.
# - **75% (Q3)**: Upper edge of the box.
# - **Max**: Upper whisker.
#
# Any points far outside these bounds would appear as *outliers*. The skew in the plot might reflect occasional bulk purchases (like Quantity = 120).

# %% [markdown]
# ### Author
#
# Yash Saxena
